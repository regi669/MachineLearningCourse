# %% [markdown]
# # Convolutional Neural Network Classifies images

# %% [markdown]
# ### Importing the libraries

# %%
import tensorflow as tf
import numpy as np
from keras.preprocessing.image import ImageDataGenerator

# %%
print(tf.__version__)
# Out:
# 2.8.0

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %% [markdown]
# ### Preprocessing the Training set

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True)
training_set = train_datagen.flow_from_directory('dataset/training_set',
                                                 target_size=(64, 64),
                                                 batch_size=32,
                                                 class_mode='binary')
# Out:
# Found 8000 images belonging to 2 classes.

# %% [markdown]
# ### Preprocessing the Test set

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
test_set = test_datagen.flow_from_directory('dataset/test_set',
                                            target_size=(64, 64),
                                            batch_size=32,
                                            class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# ## Part 2 - Building the CNN

# %% [markdown]
# ### Initialising the CNN

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# ### Step 1 - Convolution

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32,
               kernel_size=3,
               activation='relu',
               input_shape=[64, 64, 3]))

# %% [markdown]
# ### Step 2 - Pooling

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,
                  strides=2,
                  padding='valid'))

# %% [markdown]
# ### Adding a second convolutional layer

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32,
               kernel_size=3,
               activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,
                  strides=2,
                  padding='valid'))

# %% [markdown]
# ### Step 3 - Flattening

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# ### Step 4 - Full Connection

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %% [markdown]
# ### Step 5 - Output Layer

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# ## Part 3 - Training the CNN

# %% [markdown]
# ### Compiling the CNN

# %%
cnn.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Training the CNN on the Training set and evaluating it on the Test set

# %%
cnn.fit(x=training_set, validation_data=test_set, epochs=25)
# Out:
# Epoch 1/25
# 250/250 [==============================] - 41s 162ms/step - loss: 0.6983 - accuracy: 0.5414 - val_loss: 0.6633 - val_accuracy: 0.5885
# Epoch 2/25
# 250/250 [==============================] - 27s 109ms/step - loss: 0.6528 - accuracy: 0.6212 - val_loss: 0.6277 - val_accuracy: 0.6575
# Epoch 3/25
# 250/250 [==============================] - 27s 108ms/step - loss: 0.6210 - accuracy: 0.6506 - val_loss: 0.6167 - val_accuracy: 0.6545
# Epoch 4/25
# 250/250 [==============================] - 28s 110ms/step - loss: 0.5805 - accuracy: 0.6944 - val_loss: 0.5838 - val_accuracy: 0.7020
# Epoch 5/25
# 250/250 [==============================] - 28s 113ms/step - loss: 0.5454 - accuracy: 0.7164 - val_loss: 0.5599 - val_accuracy: 0.7130
# Epoch 6/25
# 250/250 [==============================] - 28s 111ms/step - loss: 0.5255 - accuracy: 0.7379 - val_loss: 0.5583 - val_accuracy: 0.7115
# Epoch 7/25
# 250/250 [==============================] - 28s 111ms/step - loss: 0.4962 - accuracy: 0.7540 - val_loss: 0.5243 - val_accuracy: 0.7485
# Epoch 8/25
# 250/250 [==============================] - 30s 121ms/step - loss: 0.4849 - accuracy: 0.7669 - val_loss: 0.5253 - val_accuracy: 0.7450
# Epoch 9/25
# 250/250 [==============================] - 28s 114ms/step - loss: 0.4638 - accuracy: 0.7747 - val_loss: 0.5099 - val_accuracy: 0.7610
# Epoch 10/25
# 250/250 [==============================] - 28s 112ms/step - loss: 0.4453 - accuracy: 0.7906 - val_loss: 0.4992 - val_accuracy: 0.7685
# Epoch 11/25
# 250/250 [==============================] - 28s 112ms/step - loss: 0.4327 - accuracy: 0.7928 - val_loss: 0.4767 - val_accuracy: 0.7765
# Epoch 12/25
# 250/250 [==============================] - 28s 112ms/step - loss: 0.4147 - accuracy: 0.8091 - val_loss: 0.5243 - val_accuracy: 0.7650
# Epoch 13/25
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3999 - accuracy: 0.8175 - val_loss: 0.4793 - val_accuracy: 0.7770
# Epoch 14/25
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3879 - accuracy: 0.8238 - val_loss: 0.4766 - val_accuracy: 0.7825
# Epoch 15/25
# 250/250 [==============================] - 29s 114ms/step - loss: 0.3726 - accuracy: 0.8339 - val_loss: 0.5649 - val_accuracy: 0.7595
# Epoch 16/25
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3560 - accuracy: 0.8409 - val_loss: 0.5250 - val_accuracy: 0.7740
# Epoch 17/25
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3417 - accuracy: 0.8511 - val_loss: 0.4836 - val_accuracy: 0.7915
# Epoch 18/25
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3225 - accuracy: 0.8559 - val_loss: 0.5298 - val_accuracy: 0.7740
# Epoch 19/25
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3213 - accuracy: 0.8640 - val_loss: 0.4917 - val_accuracy: 0.7790
# Epoch 20/25
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3040 - accuracy: 0.8680 - val_loss: 0.6193 - val_accuracy: 0.7555
# Epoch 21/25
# 250/250 [==============================] - 28s 112ms/step - loss: 0.2878 - accuracy: 0.8770 - val_loss: 0.5022 - val_accuracy: 0.8000
# Epoch 22/25
# 250/250 [==============================] - 29s 114ms/step - loss: 0.2760 - accuracy: 0.8850 - val_loss: 0.6230 - val_accuracy: 0.7640
# Epoch 23/25
# 250/250 [==============================] - 28s 113ms/step - loss: 0.2527 - accuracy: 0.8956 - val_loss: 0.5506 - val_accuracy: 0.7790
# Epoch 24/25
# 250/250 [==============================] - 28s 112ms/step - loss: 0.2400 - accuracy: 0.8976 - val_loss: 0.6638 - val_accuracy: 0.7630
# Epoch 25/25
# 250/250 [==============================] - 28s 113ms/step - loss: 0.2260 - accuracy: 0.9068 - val_loss: 0.6611 - val_accuracy: 0.7640

# %% [markdown]
# ## Part 4 - Making a single prediction

# %%
from keras.preprocessing import image
test_image = image.load_img('dataset/single_prediction/cat_or_dog_3.jpg',
                            target_size=[64, 64])
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)
result = cnn.predict(test_image)
print(training_set.class_indices)
if result[0][0] == 1:
    prediction = 'Dog'
else:
    prediction = 'Cat'
# Out:
# {'cats': 0, 'dogs': 1}

# %%
print(prediction)
# Out:
# Cat

# %%
cnn.save('Cat_Or_Dog')
# Out:
# INFO:tensorflow:Assets written to: Cat_Or_Dog\assets

# %%
reused_model = tf.keras.models.load_model('Cat_Or_Dog')

# %%
new_result = reused_model.predict(test_image)
if new_result[0][0] == 1:
    prediction = 'Dog'
else:
    prediction = 'Cat'
print(prediction)
# Out:
# Cat
